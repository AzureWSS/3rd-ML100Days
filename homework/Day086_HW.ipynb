# %% [markdown]
# ## Work
# 1. 試比較 save_best_only 與否的差異
# 2. 請僅存入將 save_weights_only 設定為 True, 並嘗試 reset ipynb 並將模型與權重重新建回並預測 x_test

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

"""
建立神經網路，並加入 BN layer
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
"""Code Here
設定 callbacks: model checkpoint
"""
"""
# 載入 Callbacks, 並將監控目標設為 validation loss, 且只存最佳參數時的模型
"""
from keras.callbacks import ModelCheckpoint
from keras.models import load_model

model_ckpt = ModelCheckpoint(filepath="./tmp2.h5", 
                             monitor="val_loss",
                             save_best_only=True,
                             save_weights_only=True)
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[model_ckpt]
         )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

# Load back
model = build_mlp(input_shape=x_train.shape[1:])
model.load_weights("./tmp2.h5")
#model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)
model.predict(x_test)
# Out:
# Model: "model_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_16 (InputLayer)        (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 3s 51us/step - loss: 2.1979 - accuracy: 0.2696 - val_loss: 2.1451 - val_accuracy: 0.2054
# Epoch 2/50
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.7400 - accuracy: 0.3945 - val_loss: 2.0055 - val_accuracy: 0.2824
# Epoch 3/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 1.6100 - accuracy: 0.4399 - val_loss: 1.8209 - val_accuracy: 0.3679
# Epoch 4/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 1.5368 - accuracy: 0.4647 - val_loss: 1.7142 - val_accuracy: 0.4073
# Epoch 5/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 1.4813 - accuracy: 0.4835 - val_loss: 1.6264 - val_accuracy: 0.4361
# Epoch 6/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 1.4360 - accuracy: 0.4996 - val_loss: 1.5965 - val_accuracy: 0.4409
# Epoch 7/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 1.3969 - accuracy: 0.5115 - val_loss: 1.5515 - val_accuracy: 0.4544
# Epoch 8/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 1.3592 - accuracy: 0.5263 - val_loss: 1.5134 - val_accuracy: 0.4666
# Epoch 9/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.3269 - accuracy: 0.5386 - val_loss: 1.5075 - val_accuracy: 0.4717
# Epoch 10/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.2967 - accuracy: 0.5499 - val_loss: 1.4891 - val_accuracy: 0.4797
# Epoch 11/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 1.2681 - accuracy: 0.5616 - val_loss: 1.4874 - val_accuracy: 0.4769
# Epoch 12/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.2398 - accuracy: 0.5713 - val_loss: 1.4752 - val_accuracy: 0.4868
# Epoch 13/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 1.2131 - accuracy: 0.5816 - val_loss: 1.4713 - val_accuracy: 0.4810
# Epoch 14/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 1.1883 - accuracy: 0.5918 - val_loss: 1.4706 - val_accuracy: 0.4803
# Epoch 15/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.1632 - accuracy: 0.6005 - val_loss: 1.4667 - val_accuracy: 0.4908
# Epoch 16/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 1.1382 - accuracy: 0.6095 - val_loss: 1.4581 - val_accuracy: 0.4867
# Epoch 17/50
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.1178 - accuracy: 0.6191 - val_loss: 1.4625 - val_accuracy: 0.4906
# Epoch 18/50
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.0960 - accuracy: 0.6252 - val_loss: 1.4575 - val_accuracy: 0.4953
# Epoch 19/50
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.0706 - accuracy: 0.6365 - val_loss: 1.4542 - val_accuracy: 0.4962
# Epoch 20/50
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.0499 - accuracy: 0.6437 - val_loss: 1.4627 - val_accuracy: 0.4906
# Epoch 21/50
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.0297 - accuracy: 0.6522 - val_loss: 1.4596 - val_accuracy: 0.4931
# Epoch 22/50
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.0057 - accuracy: 0.6599 - val_loss: 1.4543 - val_accuracy: 0.4978
# Epoch 23/50
# 50000/50000 [==============================] - 2s 42us/step - loss: 0.9851 - accuracy: 0.6681 - val_loss: 1.4567 - val_accuracy: 0.4952
# Epoch 24/50
# 50000/50000 [==============================] - 2s 42us/step - loss: 0.9650 - accuracy: 0.6763 - val_loss: 1.4534 - val_accuracy: 0.4969
# Epoch 25/50
# 50000/50000 [==============================] - 2s 42us/step - loss: 0.9447 - accuracy: 0.6848 - val_loss: 1.4517 - val_accuracy: 0.4959
# Epoch 26/50
# 50000/50000 [==============================] - 2s 42us/step - loss: 0.9248 - accuracy: 0.6921 - val_loss: 1.4774 - val_accuracy: 0.4958
# Epoch 27/50
# 50000/50000 [==============================] - 2s 42us/step - loss: 0.9045 - accuracy: 0.6977 - val_loss: 1.4598 - val_accuracy: 0.4986
# Epoch 28/50
# 50000/50000 [==============================] - 2s 42us/step - loss: 0.8826 - accuracy: 0.7062 - val_loss: 1.4635 - val_accuracy: 0.5026
# Epoch 29/50
# 50000/50000 [==============================] - 2s 42us/step - loss: 0.8623 - accuracy: 0.7166 - val_loss: 1.4695 - val_accuracy: 0.5028
# Epoch 30/50
# 50000/50000 [==============================] - 2s 42us/step - loss: 0.8424 - accuracy: 0.7242 - val_loss: 1.4902 - val_accuracy: 0.4952
# Epoch 31/50
# 50000/50000 [==============================] - 2s 42us/step - loss: 0.8239 - accuracy: 0.7314 - val_loss: 1.4924 - val_accuracy: 0.4984
# Epoch 32/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.8033 - accuracy: 0.7398 - val_loss: 1.5146 - val_accuracy: 0.4904
# Epoch 33/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.7854 - accuracy: 0.7463 - val_loss: 1.4969 - val_accuracy: 0.4985
# Epoch 34/50
# 50000/50000 [==============================] - 2s 42us/step - loss: 0.7658 - accuracy: 0.7533 - val_loss: 1.5165 - val_accuracy: 0.4955
# Epoch 35/50
# 50000/50000 [==============================] - 2s 42us/step - loss: 0.7461 - accuracy: 0.7630 - val_loss: 1.5143 - val_accuracy: 0.4988
# Epoch 36/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.7271 - accuracy: 0.7697 - val_loss: 1.5208 - val_accuracy: 0.4969
# Epoch 37/50
# 50000/50000 [==============================] - 2s 42us/step - loss: 0.7095 - accuracy: 0.7765 - val_loss: 1.5248 - val_accuracy: 0.4959
# Epoch 38/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.6902 - accuracy: 0.7832 - val_loss: 1.5363 - val_accuracy: 0.5013
# Epoch 39/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.6712 - accuracy: 0.7923 - val_loss: 1.5409 - val_accuracy: 0.4998
# Epoch 40/50
# 50000/50000 [==============================] - 2s 42us/step - loss: 0.6560 - accuracy: 0.7966 - val_loss: 1.5567 - val_accuracy: 0.4996
# Epoch 41/50
# 50000/50000 [==============================] - 2s 42us/step - loss: 0.6355 - accuracy: 0.8060 - val_loss: 1.5550 - val_accuracy: 0.5013
# Epoch 42/50
# 50000/50000 [==============================] - 2s 42us/step - loss: 0.6166 - accuracy: 0.8130 - val_loss: 1.5765 - val_accuracy: 0.4990
# Epoch 43/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.6017 - accuracy: 0.8188 - val_loss: 1.5906 - val_accuracy: 0.4966
# Epoch 44/50
# 50000/50000 [==============================] - 2s 42us/step - loss: 0.5824 - accuracy: 0.8265 - val_loss: 1.5954 - val_accuracy: 0.4946
# Epoch 45/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.5678 - accuracy: 0.8310 - val_loss: 1.6339 - val_accuracy: 0.4942
# Epoch 46/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.5491 - accuracy: 0.8406 - val_loss: 1.6196 - val_accuracy: 0.4986
# Epoch 47/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.5355 - accuracy: 0.8455 - val_loss: 1.6261 - val_accuracy: 0.4940
# Epoch 48/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.5149 - accuracy: 0.8543 - val_loss: 1.6395 - val_accuracy: 0.4929
# Epoch 49/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.5011 - accuracy: 0.8581 - val_loss: 1.6728 - val_accuracy: 0.4875
# Epoch 50/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.4856 - accuracy: 0.8642 - val_loss: 1.6685 - val_accuracy: 0.4905
# array([[1.2105875e-02, 2.3290474e-02, 8.4244601e-02, ..., 1.3344949e-04,
#         6.5013997e-02, 3.8980974e-03],
#        [9.0924539e-03, 5.9021629e-02, 4.4941439e-04, ..., 1.1137337e-03,
#         5.5430245e-01, 3.7316635e-01],
#        [6.2881756e-01, 5.1777497e-02, 2.8263051e-03, ..., 4.1372990e-03,
#         2.2380184e-01, 8.7624863e-02],
#        ...,
#        [2.1137339e-03, 1.5959553e-04, 4.2217928e-01, ..., 4.9389422e-02,
#         7.4701221e-04, 2.3427856e-04],
#        [3.3013385e-02, 1.5086072e-02, 2.9928574e-01, ..., 9.3302224e-03,
#         6.9482732e-03, 6.0597975e-03],
#        [3.5030644e-02, 3.5620602e-03, 6.7281291e-02, ..., 1.8291657e-01,
#         1.0537331e-02, 4.1633365e-03]], dtype=float32)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
#plt.hlines(y=loss_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
#plt.hlines(y=acc_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
plt.legend()
plt.title("Accuracy")
plt.show()
