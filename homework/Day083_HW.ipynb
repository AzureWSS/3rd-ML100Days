# %% [markdown]
# ## Work
# 1. 試比較有 BN 在 Batch_size = 2, 16, 32, 128, 256 下的差異
# 2. 請嘗試將 BN 放在 Activation 之前，並比較訓練結果
# 3. 請於 BN 放在 Input Layer 後，並比較結果

# %%
import os
import keras
import itertools
# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.
# C:\Anaconda3\lib\site-packages\pandas\compat\_optional.py:106: UserWarning: Pandas requires version '1.2.1' or newer of 'bottleneck' (version '1.2.0' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

"""
建立神經網路，並加入 BN layer
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    x = BatchNormalization()
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 2s 45us/step - loss: 2.2272 - accuracy: 0.1788 - val_loss: 2.0953 - val_accuracy: 0.2566
# Epoch 2/50
# 50000/50000 [==============================] - 2s 37us/step - loss: 2.0258 - accuracy: 0.2852 - val_loss: 1.9628 - val_accuracy: 0.3096
# Epoch 3/50
# 50000/50000 [==============================] - 2s 37us/step - loss: 1.9271 - accuracy: 0.3209 - val_loss: 1.8911 - val_accuracy: 0.3383
# Epoch 4/50
# 50000/50000 [==============================] - 2s 37us/step - loss: 1.8695 - accuracy: 0.3431 - val_loss: 1.8439 - val_accuracy: 0.3549
# Epoch 5/50
# 50000/50000 [==============================] - 2s 37us/step - loss: 1.8280 - accuracy: 0.3610 - val_loss: 1.8074 - val_accuracy: 0.3691
# Epoch 6/50
#  - ETA: 0s - loss: 1.8026 - accuracy: 0.3708
# Epoch 7/50
# 50000/50000 [==============================] - 2s 39us/step - loss: 1.7668 - accuracy: 0.3845 - val_loss: 1.7548 - val_accuracy: 0.3864
# Epoch 8/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.7441 - accuracy: 0.3934 - val_loss: 1.7310 - val_accuracy: 0.3962
# Epoch 9/50
# 50000/50000 [==============================] - 2s 38us/step - loss: 1.7228 - accuracy: 0.4004 - val_loss: 1.7129 - val_accuracy: 0.4030
# Epoch 10/50
# 50000/50000 [==============================] - 2s 38us/step - loss: 1.7046 - accuracy: 0.4066 - val_loss: 1.6953 - val_accuracy: 0.4086
# Epoch 11/50
# 50000/50000 [==============================] - 2s 37us/step - loss: 1.6873 - accuracy: 0.4132 - val_loss: 1.6793 - val_accuracy: 0.4124
# Epoch 12/50
# 50000/50000 [==============================] - 2s 38us/step - loss: 1.6716 - accuracy: 0.4186 - val_loss: 1.6666 - val_accuracy: 0.4172
# Epoch 13/50
# 50000/50000 [==============================] - 2s 38us/step - loss: 1.6563 - accuracy: 0.4252 - val_loss: 1.6516 - val_accuracy: 0.4228
# Epoch 14/50
# 50000/50000 [==============================] - 2s 38us/step - loss: 1.6426 - accuracy: 0.4290 - val_loss: 1.6380 - val_accuracy: 0.4279
# Epoch 15/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 1.6290 - accuracy: 0.4337 - val_loss: 1.6269 - val_accuracy: 0.4332
# Epoch 16/50
#  - ETA: 0s - loss: 1.6243 - accuracy: 0.4353
# Epoch 17/50
# 50000/50000 [==============================] - 2s 39us/step - loss: 1.6049 - accuracy: 0.4404 - val_loss: 1.6051 - val_accuracy: 0.4380
# Epoch 18/50
# 50000/50000 [==============================] - 2s 38us/step - loss: 1.5924 - accuracy: 0.4459 - val_loss: 1.5947 - val_accuracy: 0.4413
# Epoch 19/50
# 50000/50000 [==============================] - 2s 38us/step - loss: 1.5812 - accuracy: 0.4496 - val_loss: 1.5877 - val_accuracy: 0.4410
# Epoch 20/50
# 50000/50000 [==============================] - 2s 39us/step - loss: 1.5708 - accuracy: 0.4526 - val_loss: 1.5799 - val_accuracy: 0.4460
# Epoch 21/50
#  - ETA: 0s - loss: 1.5602 - accuracy: 0.4564
# Epoch 22/50
# 50000/50000 [==============================] - 2s 39us/step - loss: 1.5511 - accuracy: 0.4595 - val_loss: 1.5628 - val_accuracy: 0.4529
# Epoch 23/50
# 50000/50000 [==============================] - 2s 37us/step - loss: 1.5413 - accuracy: 0.4630 - val_loss: 1.5584 - val_accuracy: 0.4510
# Epoch 24/50
# 50000/50000 [==============================] - 2s 37us/step - loss: 1.5322 - accuracy: 0.4656 - val_loss: 1.5469 - val_accuracy: 0.4567
# Epoch 25/50
# 50000/50000 [==============================] - 2s 38us/step - loss: 1.5241 - accuracy: 0.4672 - val_loss: 1.5402 - val_accuracy: 0.4598
# Epoch 26/50
# 50000/50000 [==============================] - 2s 36us/step - loss: 1.5147 - accuracy: 0.4712 - val_loss: 1.5366 - val_accuracy: 0.4573
# Epoch 27/50
# 50000/50000 [==============================] - 2s 36us/step - loss: 1.5066 - accuracy: 0.4746 - val_loss: 1.5299 - val_accuracy: 0.4590
# Epoch 28/50
# 50000/50000 [==============================] - 2s 37us/step - loss: 1.4986 - accuracy: 0.4771 - val_loss: 1.5195 - val_accuracy: 0.4657
# Epoch 29/50
# 50000/50000 [==============================] - 2s 37us/step - loss: 1.4903 - accuracy: 0.4790 - val_loss: 1.5132 - val_accuracy: 0.4658
# Epoch 30/50
# 50000/50000 [==============================] - 2s 37us/step - loss: 1.4827 - accuracy: 0.4830 - val_loss: 1.5085 - val_accuracy: 0.4671
# Epoch 31/50
# 50000/50000 [==============================] - 2s 36us/step - loss: 1.4751 - accuracy: 0.4858 - val_loss: 1.5030 - val_accuracy: 0.4696
# Epoch 32/50
# 50000/50000 [==============================] - 2s 37us/step - loss: 1.4675 - accuracy: 0.4893 - val_loss: 1.4983 - val_accuracy: 0.4725
# Epoch 33/50
# 50000/50000 [==============================] - 2s 36us/step - loss: 1.4596 - accuracy: 0.4914 - val_loss: 1.4929 - val_accuracy: 0.4724
# Epoch 34/50
# 50000/50000 [==============================] - 2s 36us/step - loss: 1.4521 - accuracy: 0.4928 - val_loss: 1.4918 - val_accuracy: 0.4723
# Epoch 35/50
# 50000/50000 [==============================] - 2s 38us/step - loss: 1.4449 - accuracy: 0.4952 - val_loss: 1.4892 - val_accuracy: 0.4733
# Epoch 36/50
# 50000/50000 [==============================] - 2s 37us/step - loss: 1.4369 - accuracy: 0.4995 - val_loss: 1.4761 - val_accuracy: 0.4780
# Epoch 37/50
# 50000/50000 [==============================] - 2s 38us/step - loss: 1.4304 - accuracy: 0.5004 - val_loss: 1.4734 - val_accuracy: 0.4795
# Epoch 38/50
# 50000/50000 [==============================] - 2s 38us/step - loss: 1.4230 - accuracy: 0.5037 - val_loss: 1.4667 - val_accuracy: 0.4794
# Epoch 39/50
# 50000/50000 [==============================] - 2s 39us/step - loss: 1.4161 - accuracy: 0.5061 - val_loss: 1.4626 - val_accuracy: 0.4821
# Epoch 40/50
# 50000/50000 [==============================] - 2s 38us/step - loss: 1.4095 - accuracy: 0.5085 - val_loss: 1.4570 - val_accuracy: 0.4806
# Epoch 41/50
# 50000/50000 [==============================] - 2s 38us/step - loss: 1.4017 - accuracy: 0.5110 - val_loss: 1.4529 - val_accuracy: 0.4848
# Epoch 42/50
# 50000/50000 [==============================] - 2s 38us/step - loss: 1.3957 - accuracy: 0.5125 - val_loss: 1.4460 - val_accuracy: 0.4876
# Epoch 43/50
# 50000/50000 [==============================] - 2s 38us/step - loss: 1.3895 - accuracy: 0.5143 - val_loss: 1.4436 - val_accuracy: 0.4883
# Epoch 44/50
#  - ETA: 0s - loss: 1.3784 - accuracy: 0.5185
# Epoch 45/50
# 50000/50000 [==============================] - 2s 38us/step - loss: 1.3744 - accuracy: 0.5210 - val_loss: 1.4389 - val_accuracy: 0.4920
# Epoch 46/50
# 50000/50000 [==============================] - 2s 38us/step - loss: 1.3682 - accuracy: 0.5213 - val_loss: 1.4394 - val_accuracy: 0.4919
# Epoch 47/50
# 50000/50000 [==============================] - 2s 37us/step - loss: 1.3617 - accuracy: 0.5248 - val_loss: 1.4265 - val_accuracy: 0.4964
# Epoch 48/50
# 50000/50000 [==============================] - 2s 38us/step - loss: 1.3558 - accuracy: 0.5258 - val_loss: 1.4250 - val_accuracy: 0.4956
# Epoch 49/50
# 50000/50000 [==============================] - 2s 38us/step - loss: 1.3497 - accuracy: 0.5286 - val_loss: 1.4233 - val_accuracy: 0.4963
# Epoch 50/50
# 50000/50000 [==============================] - 2s 38us/step - loss: 1.3430 - accuracy: 0.5299 - val_loss: 1.4161 - val_accuracy: 0.4981

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()
