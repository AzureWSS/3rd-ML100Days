# %% [markdown]
# ## Work
# 1. 請比較使用不同層數以及不同 Dropout rate 對訓練的效果
# 2. 將 optimizer 改成使用 Adam 並加上適當的 dropout rate 檢視結果

# %%
import os
import keras
import itertools
# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.
# C:\Anaconda3\lib\site-packages\pandas\compat\_optional.py:106: UserWarning: Pandas requires version '1.2.1' or newer of 'bottleneck' (version '1.2.0' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import Dropout

"""
建立神經網路，並加入 dropout layer
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128], drp_ratio=0.3):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = Dropout(drp_ratio)(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = Dropout(drp_ratio)(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 256
MOMENTUM = 0.95
Dropout_EXP = 0.2

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
model = build_mlp(input_shape=x_train.shape[1:], drp_ratio=Dropout_EXP)
model.summary()
#optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
optimizer = keras.optimizers.Adam(lr=0.001, decay=0.0)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 3s 65us/step - loss: 2.0489 - accuracy: 0.2465 - val_loss: 1.8098 - val_accuracy: 0.3547
# Epoch 2/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 1.8493 - accuracy: 0.3311 - val_loss: 1.7262 - val_accuracy: 0.3772
# Epoch 3/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 1.7825 - accuracy: 0.3568 - val_loss: 1.6816 - val_accuracy: 0.4080
# Epoch 4/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 1.7456 - accuracy: 0.3711 - val_loss: 1.6309 - val_accuracy: 0.4187
# Epoch 5/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.7000 - accuracy: 0.3875 - val_loss: 1.6037 - val_accuracy: 0.4293
# Epoch 6/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.6787 - accuracy: 0.3979 - val_loss: 1.5717 - val_accuracy: 0.4377
# Epoch 7/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 1.6498 - accuracy: 0.4060 - val_loss: 1.5568 - val_accuracy: 0.4461
# Epoch 8/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 1.6344 - accuracy: 0.4139 - val_loss: 1.5590 - val_accuracy: 0.4422
# Epoch 9/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.6145 - accuracy: 0.4175 - val_loss: 1.5411 - val_accuracy: 0.4511
# Epoch 10/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.5954 - accuracy: 0.4273 - val_loss: 1.5400 - val_accuracy: 0.4514
# Epoch 11/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.5814 - accuracy: 0.4316 - val_loss: 1.5011 - val_accuracy: 0.4620
# Epoch 12/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.5775 - accuracy: 0.4325 - val_loss: 1.5320 - val_accuracy: 0.4560
# Epoch 13/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.5695 - accuracy: 0.4360 - val_loss: 1.4794 - val_accuracy: 0.4693
# Epoch 14/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.5517 - accuracy: 0.4394 - val_loss: 1.4934 - val_accuracy: 0.4666
# Epoch 15/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.5473 - accuracy: 0.4441 - val_loss: 1.4785 - val_accuracy: 0.4734
# Epoch 16/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.5372 - accuracy: 0.4481 - val_loss: 1.4529 - val_accuracy: 0.4841
# Epoch 17/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.5249 - accuracy: 0.4521 - val_loss: 1.4639 - val_accuracy: 0.4776
# Epoch 18/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.5229 - accuracy: 0.4533 - val_loss: 1.4684 - val_accuracy: 0.4697
# Epoch 19/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.5204 - accuracy: 0.4538 - val_loss: 1.4709 - val_accuracy: 0.4704
# Epoch 20/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.5071 - accuracy: 0.4568 - val_loss: 1.4962 - val_accuracy: 0.4685
# Epoch 21/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.5023 - accuracy: 0.4600 - val_loss: 1.4708 - val_accuracy: 0.4747
# Epoch 22/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.5004 - accuracy: 0.4599 - val_loss: 1.4312 - val_accuracy: 0.4912
# Epoch 23/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 1.4908 - accuracy: 0.4646 - val_loss: 1.4690 - val_accuracy: 0.4805
# Epoch 24/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.4995 - accuracy: 0.4617 - val_loss: 1.4609 - val_accuracy: 0.4844
# Epoch 25/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 1.4917 - accuracy: 0.4615 - val_loss: 1.4222 - val_accuracy: 0.4893
# Epoch 26/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.4773 - accuracy: 0.4705 - val_loss: 1.4164 - val_accuracy: 0.5004
# Epoch 27/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.4731 - accuracy: 0.4714 - val_loss: 1.4459 - val_accuracy: 0.4936
# Epoch 28/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.4829 - accuracy: 0.4652 - val_loss: 1.4318 - val_accuracy: 0.4907
# Epoch 29/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.4733 - accuracy: 0.4699 - val_loss: 1.4426 - val_accuracy: 0.4818
# Epoch 30/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 1.4609 - accuracy: 0.4752 - val_loss: 1.4171 - val_accuracy: 0.4920
# Epoch 31/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 1.4635 - accuracy: 0.4726 - val_loss: 1.4294 - val_accuracy: 0.4931
# Epoch 32/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.4582 - accuracy: 0.4745 - val_loss: 1.4075 - val_accuracy: 0.5038
# Epoch 33/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 1.4537 - accuracy: 0.4793 - val_loss: 1.4298 - val_accuracy: 0.4891
# Epoch 34/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.4599 - accuracy: 0.4777 - val_loss: 1.4268 - val_accuracy: 0.4928
# Epoch 35/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 1.4397 - accuracy: 0.4842 - val_loss: 1.4349 - val_accuracy: 0.4970
# Epoch 36/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.4432 - accuracy: 0.4807 - val_loss: 1.4059 - val_accuracy: 0.4983
# Epoch 37/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.4347 - accuracy: 0.4826 - val_loss: 1.4082 - val_accuracy: 0.4994
# Epoch 38/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.4295 - accuracy: 0.4886 - val_loss: 1.4257 - val_accuracy: 0.4893
# Epoch 39/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 1.4317 - accuracy: 0.4856 - val_loss: 1.4126 - val_accuracy: 0.4996
# Epoch 40/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.4311 - accuracy: 0.4871 - val_loss: 1.4281 - val_accuracy: 0.4964
# Epoch 41/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.4200 - accuracy: 0.4897 - val_loss: 1.4287 - val_accuracy: 0.4878
# Epoch 42/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 1.4272 - accuracy: 0.4856 - val_loss: 1.4128 - val_accuracy: 0.4986
# Epoch 43/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.4206 - accuracy: 0.4903 - val_loss: 1.4062 - val_accuracy: 0.5047
# Epoch 44/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 1.4149 - accuracy: 0.4925 - val_loss: 1.3937 - val_accuracy: 0.5033
# Epoch 45/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 1.4156 - accuracy: 0.4921 - val_loss: 1.4188 - val_accuracy: 0.4931
# Epoch 46/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 1.4130 - accuracy: 0.4929 - val_loss: 1.3948 - val_accuracy: 0.5070
# Epoch 47/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 1.4110 - accuracy: 0.4964 - val_loss: 1.4085 - val_accuracy: 0.4966
# Epoch 48/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 1.4003 - accuracy: 0.4978 - val_loss: 1.4050 - val_accuracy: 0.4978
# Epoch 49/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 1.3995 - accuracy: 0.4983 - val_loss: 1.4280 - val_accuracy: 0.4957
# Epoch 50/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 1.4075 - accuracy: 0.4918 - val_loss: 1.4081 - val_accuracy: 0.5007

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()
