# %% [markdown]
# ## Work
# 1. 請嘗試寫一個 callback 用來記錄各類別在訓練過程中，對驗證集的 True Positive 與 True Negative

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

"""
建立神經網路，並加入 BN layer
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 25
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
from keras.callbacks import Callback
import numpy as np
# Record_fp_tp
class Record_tp_tn(Callback):
    def on_train_begin(self, epoch, logs = {}):
        logs = logs or {}
        record_items = ["val_auc", "val_f1sc", "val_fp", "val_fn", "val_tp", "val_tn"]
        for i in record_items:
            if i not in self.params['metrics']:
                self.params['metrics'].append(i)
    
    def on_epoch_end(self, epoch, logs = {}, thres=0.5):
        logs = logs or {}
        y_true = self.validation_data[1].argmax(axis = 1)
        y_pred = self.model.predict(self.validation_data[0])
        y_pred = (y_pred[:, 1] >= thres) * 1
        
        logs["val_tp"] = np.sum(np.logical_and(y_pred == 1, y_true == 1))
        logs["val_tn"] = np.sum(np.logical_and(y_pred == 0, y_true == 0))
        
rec_tptn = Record_tp_tn()

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

"""Code Here
將 callbacks 放入模型訓練流程中
"""
model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[rec_tptn]
         )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

"""Code Here
將 tp/tn 從訓練完的模型中取出
"""
valid_tp = model.history.history['val_tp']
valid_tn = model.history.history['val_tn']
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 3s 53us/step - loss: 2.2202 - accuracy: 0.2725 - val_loss: 2.1310 - val_accuracy: 0.1960
# Epoch 2/25
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.7423 - accuracy: 0.3958 - val_loss: 1.9631 - val_accuracy: 0.2959
# Epoch 3/25
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.6156 - accuracy: 0.4364 - val_loss: 1.8121 - val_accuracy: 0.3691
# Epoch 4/25
# 50000/50000 [==============================] - 2s 41us/step - loss: 1.5406 - accuracy: 0.4628 - val_loss: 1.7100 - val_accuracy: 0.4069
# Epoch 5/25
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.4842 - accuracy: 0.4825 - val_loss: 1.6355 - val_accuracy: 0.4304
# Epoch 6/25
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.4402 - accuracy: 0.4967 - val_loss: 1.5894 - val_accuracy: 0.4352
# Epoch 7/25
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.3987 - accuracy: 0.5114 - val_loss: 1.5622 - val_accuracy: 0.4456
# Epoch 8/25
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.3647 - accuracy: 0.5259 - val_loss: 1.5232 - val_accuracy: 0.4661
# Epoch 9/25
# 50000/50000 [==============================] - 2s 41us/step - loss: 1.3335 - accuracy: 0.5349 - val_loss: 1.5113 - val_accuracy: 0.4612
# Epoch 10/25
# 50000/50000 [==============================] - 2s 41us/step - loss: 1.3024 - accuracy: 0.5486 - val_loss: 1.4957 - val_accuracy: 0.4691
# Epoch 11/25
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.2740 - accuracy: 0.5582 - val_loss: 1.4870 - val_accuracy: 0.4699
# Epoch 12/25
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.2463 - accuracy: 0.5674 - val_loss: 1.4886 - val_accuracy: 0.4739
# Epoch 13/25
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.2202 - accuracy: 0.5783 - val_loss: 1.4728 - val_accuracy: 0.4816
# Epoch 14/25
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.1943 - accuracy: 0.5868 - val_loss: 1.4647 - val_accuracy: 0.4820
# Epoch 15/25
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.1706 - accuracy: 0.5963 - val_loss: 1.4603 - val_accuracy: 0.4806
# Epoch 16/25
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.1462 - accuracy: 0.6054 - val_loss: 1.4575 - val_accuracy: 0.4846
# Epoch 17/25
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.1232 - accuracy: 0.6133 - val_loss: 1.4762 - val_accuracy: 0.4777
# Epoch 18/25
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.1003 - accuracy: 0.6228 - val_loss: 1.4688 - val_accuracy: 0.4831
# Epoch 19/25
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.0788 - accuracy: 0.6321 - val_loss: 1.4686 - val_accuracy: 0.4863
# Epoch 20/25
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.0560 - accuracy: 0.6398 - val_loss: 1.4780 - val_accuracy: 0.4882
# Epoch 21/25
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.0364 - accuracy: 0.6469 - val_loss: 1.4664 - val_accuracy: 0.4891
# Epoch 22/25
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.0106 - accuracy: 0.6583 - val_loss: 1.4530 - val_accuracy: 0.4941
# Epoch 23/25
# 50000/50000 [==============================] - 2s 42us/step - loss: 0.9898 - accuracy: 0.6649 - val_loss: 1.4545 - val_accuracy: 0.4930
# Epoch 24/25
# 50000/50000 [==============================] - 2s 42us/step - loss: 0.9699 - accuracy: 0.6722 - val_loss: 1.4666 - val_accuracy: 0.4878
# Epoch 25/25
# 50000/50000 [==============================] - 2s 42us/step - loss: 0.9495 - accuracy: 0.6820 - val_loss: 1.4738 - val_accuracy: 0.4911

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(range(len(valid_tp)), valid_tp, label="valid tp", color="navy")
plt.plot(range(len(valid_tn)), valid_tn, label="valid tn", color="red")
plt.legend()
plt.title("True positives and True Negatives")
plt.show()
