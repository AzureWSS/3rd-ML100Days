# %% [markdown]
# ## Work
# 1. 試改變 monitor "Validation Accuracy" 並比較結果
# 2. 調整 earlystop 的等待次數至 10, 25 並比較結果

# %%
import os
import keras
import matplotlib.pyplot as plt
# %matplotlib inline


# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.
# C:\Anaconda3\lib\site-packages\pandas\compat\_optional.py:106: UserWarning: Pandas requires version '1.2.1' or newer of 'bottleneck' (version '1.2.0' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

"""
建立神經網路，並加入 BN layer
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
"""Code Here
設定 callbacks: Earlystop
"""
"""
# 載入 Callbacks, 並將 monitor 設定為監控 validation loss
"""
from keras.callbacks import EarlyStopping

earlystop = EarlyStopping(monitor="val_accuracy", 
                          patience=10, 
                          verbose=1
                          )
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[earlystop]
         )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 2.2290 - accuracy: 0.2623 - val_loss: 2.1332 - val_accuracy: 0.2310
# Epoch 2/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 1.7530 - accuracy: 0.3874 - val_loss: 1.9742 - val_accuracy: 0.3059
# Epoch 3/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.6264 - accuracy: 0.4286 - val_loss: 1.8315 - val_accuracy: 0.3702
# Epoch 4/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.5533 - accuracy: 0.4553 - val_loss: 1.7284 - val_accuracy: 0.3947
# Epoch 5/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.4966 - accuracy: 0.4754 - val_loss: 1.6463 - val_accuracy: 0.4221
# Epoch 6/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.4524 - accuracy: 0.4915 - val_loss: 1.5812 - val_accuracy: 0.4460
# Epoch 7/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.4130 - accuracy: 0.5066 - val_loss: 1.5463 - val_accuracy: 0.4582
# Epoch 8/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.3775 - accuracy: 0.5191 - val_loss: 1.5337 - val_accuracy: 0.4583
# Epoch 9/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.3459 - accuracy: 0.5318 - val_loss: 1.5090 - val_accuracy: 0.4680
# Epoch 10/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.3162 - accuracy: 0.5423 - val_loss: 1.4910 - val_accuracy: 0.4748
# Epoch 11/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.2880 - accuracy: 0.5502 - val_loss: 1.4786 - val_accuracy: 0.4781
# Epoch 12/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.2613 - accuracy: 0.5624 - val_loss: 1.4721 - val_accuracy: 0.4771
# Epoch 13/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.2359 - accuracy: 0.5704 - val_loss: 1.4611 - val_accuracy: 0.4875
# Epoch 14/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.2089 - accuracy: 0.5809 - val_loss: 1.4681 - val_accuracy: 0.4808
# Epoch 15/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.1856 - accuracy: 0.5896 - val_loss: 1.4628 - val_accuracy: 0.4845
# Epoch 16/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.1615 - accuracy: 0.6001 - val_loss: 1.4596 - val_accuracy: 0.4860
# Epoch 17/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.1396 - accuracy: 0.6070 - val_loss: 1.4668 - val_accuracy: 0.4912
# Epoch 18/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.1150 - accuracy: 0.6150 - val_loss: 1.4553 - val_accuracy: 0.4929
# Epoch 19/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.0943 - accuracy: 0.6246 - val_loss: 1.4548 - val_accuracy: 0.4904
# Epoch 20/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.0724 - accuracy: 0.6323 - val_loss: 1.4526 - val_accuracy: 0.4917
# Epoch 21/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.0503 - accuracy: 0.6413 - val_loss: 1.4592 - val_accuracy: 0.4892
# Epoch 22/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.0287 - accuracy: 0.6486 - val_loss: 1.4613 - val_accuracy: 0.4892
# Epoch 23/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 1.0069 - accuracy: 0.6582 - val_loss: 1.4726 - val_accuracy: 0.4862
# Epoch 24/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.9857 - accuracy: 0.6671 - val_loss: 1.4606 - val_accuracy: 0.4894
# Epoch 25/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.9668 - accuracy: 0.6736 - val_loss: 1.4586 - val_accuracy: 0.4935
# Epoch 26/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.9460 - accuracy: 0.6832 - val_loss: 1.4617 - val_accuracy: 0.4945
# Epoch 27/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.9241 - accuracy: 0.6920 - val_loss: 1.4702 - val_accuracy: 0.4957
# Epoch 28/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.9050 - accuracy: 0.7000 - val_loss: 1.4674 - val_accuracy: 0.4959
# Epoch 29/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.8864 - accuracy: 0.7055 - val_loss: 1.4763 - val_accuracy: 0.4958
# Epoch 30/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.8676 - accuracy: 0.7133 - val_loss: 1.4905 - val_accuracy: 0.4903
# Epoch 31/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.8467 - accuracy: 0.7218 - val_loss: 1.4934 - val_accuracy: 0.4929
# Epoch 32/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.8260 - accuracy: 0.7299 - val_loss: 1.4974 - val_accuracy: 0.4924
# Epoch 33/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.8059 - accuracy: 0.7380 - val_loss: 1.4951 - val_accuracy: 0.4916
# Epoch 34/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.7884 - accuracy: 0.7445 - val_loss: 1.5030 - val_accuracy: 0.4911
# Epoch 35/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.7685 - accuracy: 0.7515 - val_loss: 1.5131 - val_accuracy: 0.4911
# Epoch 36/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.7503 - accuracy: 0.7607 - val_loss: 1.5281 - val_accuracy: 0.4875
# Epoch 37/50
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.7316 - accuracy: 0.7678 - val_loss: 1.5403 - val_accuracy: 0.4893
# Epoch 38/50
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.7136 - accuracy: 0.7761 - val_loss: 1.5398 - val_accuracy: 0.4876
# Epoch 00038: early stopping

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()
